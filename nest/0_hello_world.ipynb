# %% [markdown]
# # PyNEST - Hello World!

# %% [markdown]
# **Modeling networks of spiking neurons using NEST**
#
# **EITN Fall School 2024, 17.10.2024**
#
# **[Barna Zajzon](mailto:b.zajzon@fz-juelich.de)**

# %% [markdown]
# This is a basic 'Hello World!' example. Enjoy!

# %%
from matplotlib import pyplot as plt
import nest
import nest.voltage_trace
nest.ResetKernel()
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.7.0
#  Built: May 19 2024 15:53:53
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
neuron = nest.Create('iaf_psc_exp')  # create neuron
spikegenerator = nest.Create('spike_generator')  # create spike generator
spikegenerator.spike_times = [10., 50.]  # set the spike times
voltmeter = nest.Create('voltmeter')  # create voltmeter
nest.Connect(spikegenerator, neuron, syn_spec={'weight': 1e3})
nest.Connect(voltmeter, neuron)  
nest.Simulate(100.)  # simulate 100 ms
# Out:
# Oct 10 17:38:56 NodeManager::prepare_nodes [Info]:
#     Preparing 3 nodes for simulation.
#
# Oct 10 17:38:56 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 3
#     Simulation time (ms): 100
#     Number of OpenMP threads: 1
#     Number of MPI processes: 1
#
# Oct 10 17:38:56 SimulationManager::run [Info]:
#     Simulation finished.

# %%
# %matplotlib inline
nest.voltage_trace.from_device(voltmeter)
# Out:
# [[<matplotlib.lines.Line2D at 0x7f9579da8580>]]
